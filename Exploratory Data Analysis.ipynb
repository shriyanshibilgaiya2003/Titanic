# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def eda_report(df):

    print('='*60)
    print('DATASET SHAPE')
    print(df.shape)

    print('\n'+'='*60)
    print('DUPLICATES')
    print(df.duplicated().sum())
    
    print('\n' + '='*60)
    print('DATA TYPES')
    display(df.dtypes)

    print('\n' + '='*60)
    print('UNIQUE VALUES')
    display(df.nunique())

    
    print('\n'+'='*60)
    print('MISSING VALUES')
    display(
        pd.DataFrame({
            'Null Count':df.isnull().sum(),
            'Null %':round(df.isnull().mean()*100,2)
        }).sort_values('Null %',ascending=False)
    )

    print('\n'+'='*60)
    print('NUMERICAL SUMMARY')
    display(df.describe())

    print('\n'+'='*60)
    print('CATEGORICAL SUMMARY')
    display(df.describe(include='object'))

# %%
eda_report(df)
# Out:
# ...
# DATASET SHAPE
# (891, 12)
#
# ...
# DUPLICATES
# 0
#
# ...
# DATA TYPES
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ...
# UNIQUE VALUES
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64
# ...
# MISSING VALUES
#              Null Count  Null %
# Cabin               687   77.10
# Age                 177   19.87
# Embarked              2    0.22
# PassengerId           0    0.00
# Survived              0    0.00
# Pclass                0    0.00
# Name                  0    0.00
# Sex                   0    0.00
# ...

# %%
test=pd.read_csv("test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
def eda_report(test):

    print('='*60)
    print('DATASET SHAPE')
    print(test.shape)

    print('\n'+'='*60)
    print('DUPLICATES')
    print(test.duplicated().sum())
    
    print('\n' + '='*60)
    print('DATA TYPES')
    display(test.dtypes)

    print('\n' + '='*60)
    print('UNIQUE VALUES')
    display(test.nunique())


    print('\n'+'='*60)
    print('MISSING VALUES')
    display(
        pd.DataFrame({
            'Null Count':test.isnull().sum(),
            'Null %':round(test.isnull().mean()*100,2)
        }).sort_values('Null %',ascending=False)
    )

    print('\n'+'='*60)
    print('NUMERICAL SUMMARY')
    display(test.describe())

    print('\n'+'='*60)
    print('CATEGORICAL SUMMARY')
    display(test.describe(include='object'))

# %%
eda_report(test)
# Out:
# ...
# DATASET SHAPE
# (418, 11)
#
# ...
# DUPLICATES
# 0
#
# ...
# DATA TYPES
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ...
# UNIQUE VALUES
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64
# ...
# MISSING VALUES
#              Null Count  Null %
# Cabin               327   78.23
# Age                  86   20.57
# Fare                  1    0.24
# PassengerId           0    0.00
# Pclass                0    0.00
# Name                  0    0.00
# Sex                   0    0.00
# SibSp                 0    0.00
# Parch                 0    0.00
# ...

# %%
#Feature Engineering

#joins the tow tables and doing Feature Engineering
# adding new required columns

# %%
train_test = pd.concat([df, test], ignore_index=True)

# %%
train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
train_test['Survived'].value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
train_test.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# dtype: float64

# %%
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
train_test['FamilySize'] = train_test['SibSp'] + train_test['Parch'] + 1

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
train_test['FamilyType'] = np.where(train_test['FamilySize'] == 1, 'Alone',
                           np.where(train_test['FamilySize'] == 2, 'Double',
                           np.where(train_test['FamilySize'] < 5,'Small',
                           'Large')))

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['FamilyType'].value_counts()
# Out:
# Alone     790
# Double    235
# Small     202
# Large      82
# Name: FamilyType, dtype: int64

# %%
train_test.loc[train_test['FamilyType'] == 'Small','FamilySize'].value_counts()
# Out:
# 3    159
# 4     43
# Name: FamilySize, dtype: int64

# %%
train_test.loc[train_test['FamilyType'] == 'Double','FamilySize'].value_counts()
# Out:
# 2    235
# Name: FamilySize, dtype: int64

# %%
train_test.loc[train_test['FamilyType'] == 'Large','FamilySize'].value_counts()
# Out:
# 6     25
# 5     22
# 7     16
# 11    11
# 8      8
# Name: FamilySize, dtype: int64

# %%
train_test['FarePerPerson'] = train_test['Fare'] / train_test['FamilySize']

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['NameTitle'] = train_test['Name'].str.extract(' ([A-Za-z]+)\.')

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
bins=[0,2,12,19,30,60,100]
labels= ['Infans','Children','Teens','Young Adults','Adults','seniors']
train_test['Age_Group']=pd.cut(train_test['Age'],bins=bins,labels=labels,right=True)
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['TicketGroupSize'] = train_test.groupby('Ticket')['Ticket'].transform('count')

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['NameTitle'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Major         2
# Ms            2
# Lady          1
# Sir           1
# Mme           1
# Don           1
# Capt          1
# Countess      1
# Jonkheer      1
# Dona          1
# Name: NameTitle, dtype: int64

# %%
train_test['Surname'] = train_test['Name'].str.split(',').str[0]

# %%
train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Perform univeriant,bivarient and multivariant on new columns in train test dataset

# %%
## Univariate Analysis


sns.countplot(x="FamilySize",data=train_test)

plt.title("Family Size Distribution")

plt.show()

# %%
#Conclusion:

#Most passengers traveled alone or with very small families.
#Large families were relatively rare on the Titanic.
#The dataset is skewed toward smaller family sizes.

# %%
sns.countplot(data=train_test, x="Age_Group")

plt.title("Age Group Distribution")

plt.show()

# %%
#Conclusion:

#The majority of passengers belonged to the Adult age group.
#Children and Senior passengers formed a smaller portion of the dataset.
#Age distribution is not uniform across groups.

# %%
train_test["FamilyType"].value_counts().plot(kind="pie",autopct="%1.1f%%")

plt.title("Family Type Percentage")

plt.ylabel("")

plt.show()

# %%
#Conclusion:

#Most passengers traveled either alone or in small families.
#Large family groups represented only a small percentage of passengers.
#Family structure may influence survival probability.

# %%
sns.histplot(train_test["TicketGroupSize"],bins=10)

plt.title("Ticket Group Size Histogram")

plt.show()

# %%
#Conclusion:

#Most tickets were associated with only one or a few passengers.
#Very large ticket groups are uncommon.
#Ticket sharing patterns may reveal family or group travel behavior.

# %%
# Bivariate Analysis

pd.crosstab(train_test["FamilySize"],train_test["Survived"])
# Out:
# Survived    0.0  1.0
# FamilySize
# 1           374  163
# 2            72   89
# 3            43   59
# 4             8   21
# 5            12    3
# 6            19    3
# 7             8    4
# 8             6    0
# 11            7    0

# %%
family_survival = train_test.groupby('FamilySize')['Survived'].mean().reset_index()

sns.scatterplot(x='FamilySize',
                y='Survived',
                data=family_survival,
                s=100)

plt.title("Survival Rate by Family Size")
plt.show()

# %%
#Conclusion:

#Passengers traveling with a small family generally had higher survival rates.
#Extremely large families tended to have lower survival rates.
#Being completely alone or in a very large group may have reduced survival chances.

# %%
pd.crosstab(train_test["FamilyType"],train_test["Survived"])
# Out:
# Survived    0.0  1.0
# FamilyType
# Alone       374  163
# Double       72   89
# Large        52   10
# Small        51   80

# %%
train_test['FamilyType'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.ylabel('')
plt.title("Family Type Distribution")
plt.show()

# %%
#Conclusion:

#Small family groups dominate the passenger population.
#The distribution confirms that solo and small-family travelers were the majority.

# %%
pd.crosstab(train_test["Age_Group"],train_test["Survived"])
# Out:
# Survived      0.0  1.0
# Age_Group
# Infans          9   15
# Children       20   25
# Teens          56   39
# Young Adults  158   87
# Adults        164  119
# seniors        17    5

# %%
age_survival = train_test.groupby('Age_Group')['Survived'].mean().reset_index()

plt.figure(figsize=(8,5))
plt.plot(
    age_survival['Age_Group'],
    age_survival['Survived'],
    marker='o'
)

plt.title("Age Group vs Survival Rate")
plt.xlabel("Age Group")
plt.ylabel("Survival Rate")
plt.show()

# %%
#Conclusion:

#Survival rates vary significantly across age groups.
#Children often show higher survival rates due to rescue priorities.
#Some age groups were more vulnerable during evacuation.

# %%
pd.crosstab(train_test["TicketGroupSize"],train_test["Survived"])
# Out:
# Survived         0.0  1.0
# TicketGroupSize
# 1                351  130
# 2                 88   93
# 3                 35   66
# 4                 12   32
# 5                 14    7
# 6                 15    4
# 7                 19    5
# 8                  8    5
# 11                 7    0

# %%
pd.crosstab(
    train_test['TicketGroupSize'],
    train_test['Survived']
).plot(
    kind='bar',
    stacked=True
)

plt.title("Ticket Group Size vs Survival")
plt.ylabel("Count")
plt.show()

# %%
#Conclusion:

#Survival patterns differ across ticket group sizes.
#Small and medium groups appear to have better survival outcomes than very large groups.
#Group size can be a useful predictive feature.

# %%
pd.crosstab(train_test["Embarked"],train_test["Survived"])
# Out:
# Survived  0.0  1.0
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
sns.countplot(
    x="Embarked",
    hue="Survived",
    data=train_test
)

plt.title("Embarked vs Survival")
plt.show()

# %%
#Conclusion:

#Survival rates vary according to embarkation port.
#Some ports show a noticeably higher proportion of survivors.
#Embarkation location may indirectly reflect passenger class and socioeconomic status.

# %%
# multivariate analysis

# %%
survival_rate = train_test.groupby(['Pclass','Sex'])['Survived'].mean().reset_index()

sns.lineplot(
    x='Pclass',
    y='Survived',
    hue='Sex',
    marker='o',
    data=survival_rate
)

plt.title("Survival Rate by Pclass and Sex")
plt.show()

# %%
#Conclusion:

#Female passengers consistently had higher survival rates than males.
#First-class passengers had the highest survival probability.
#Passenger class and gender are among the strongest predictors of survival.

# %%
table = pd.pivot_table(
    train_test,
    values='Survived',
    index='Sex',
    columns='Age_Group'
)

sns.heatmap(
    table,
    annot=True,
    cmap='YlGnBu'
)

plt.title("Survival Rate by Age Group and Sex")
plt.show()

# %%
#Conclusion:

#Female passengers generally survived at higher rates across all age groups.
#Male survival rates were significantly lower.
#The interaction between age and gender strongly affects survival.

# %%
temp = train_test.groupby(
    ['Embarked', 'Pclass']
)['Survived'].mean().reset_index()

sns.lineplot(
    x='Embarked',
    y='Survived',
    hue='Pclass',
    marker='o',
    data=temp
)

plt.title("Survival Rate by Embarked and Pclass")
plt.show()

# %%
#Conclusion:

#Survival rates vary across both embarkation ports and passenger classes.
#First-class passengers generally maintained higher survival rates regardless of embarkation point.
#The combined effect of class and embarkation provides valuable predictive information.

# %%
cols = ['Survived','Pclass','Age','Fare','SibSp','Parch']
sns.pairplot(df[cols].dropna(),hue='Survived')
plt.show()

# %%
#Conclusion:

#Strong separation between survivors and non-survivors is visible in some variables.
#Fare and Pclass show clear relationships with survival.
#No severe linear relationship exists among all variables, but useful patterns are present.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Age',y='Fare',hue='Survived',style='Sex')
plt.title("Age vs Fare with Survival")
plt.show()

# %%
#Conclusion:

#Passengers paying higher fares generally had better survival chances.
#Survival is observed across all age groups but is more frequent among high-fare passengers.
#Fare appears to be a stronger predictor than age alone.

# %% [markdown]
# DATA CLEANING

# %%
train_test.isnull().mean()*100
# Out:
# PassengerId         0.000000
# Survived           31.932773
# Pclass              0.000000
# Name                0.000000
# Sex                 0.000000
# Age                20.091673
# SibSp               0.000000
# Parch               0.000000
# Ticket              0.000000
# Fare                0.076394
# Cabin              77.463713
# Embarked            0.152788
# FamilySize          0.000000
# FamilyType          0.000000
# FarePerPerson       0.076394
# NameTitle           0.000000
# Age_Group          20.091673
# TicketGroupSize     0.000000
# Surname             0.000000
# dtype: float64

# %%
eda_report(train_test)
# Out:
# ...
# DATASET SHAPE
# (1309, 19)
#
# ...
# DUPLICATES
# 0
#
# ...
# DATA TYPES
# PassengerId           int64
# Survived            float64
# Pclass                int64
# Name                 object
# Sex                  object
# Age                 float64
# SibSp                 int64
# Parch                 int64
# Ticket               object
# Fare                float64
# Cabin                object
# Embarked             object
# FamilySize            int64
# FamilyType           object
# FarePerPerson       float64
# NameTitle            object
# Age_Group          category
# TicketGroupSize       int64
# Surname              object
# dtype: object
# ...
# UNIQUE VALUES
# PassengerId        1309
# Survived              2
# Pclass                3
# Name               1307
# Sex                   2
# Age                  98
# SibSp                 7
# Parch                 8
# Ticket              929
# Fare                281
# Cabin               186
# Embarked              3
# ...

# %%
def compare_age_fill_visualization(train_test):

    # Original variance
    original_var = train_test['Age'].var()

    # Mean Fill
    mean_age = train_test['Age'].fillna(train_test['Age'].mean())
    mean_var = mean_age.var()

    # Median Fill
    median_age = train_test['Age'].fillna(train_test['Age'].median())
    median_var = median_age.var()

    # Random Fill
    random_age = train_test['Age'].copy()

    random_values = train_test['Age'].dropna().sample(
        train_test['Age'].isnull().sum(),
        replace=True,
        random_state=42
    )

    random_age[random_age.isnull()] = random_values.values
    random_var = random_age.var()

    # Visualization
    fig, axes = plt.subplots(1, 3, figsize=(18,5))

    sns.histplot(mean_age, kde=True, ax=axes[0])
    axes[0].set_title(f"Mean Fill\nVariance = {mean_var:.2f}")

    sns.histplot(median_age, kde=True, ax=axes[1])
    axes[1].set_title(f"Median Fill\nVariance = {median_var:.2f}")

    sns.histplot(random_age, kde=True, ax=axes[2])
    axes[2].set_title(f"Random Fill\nVariance = {random_var:.2f}")

    plt.tight_layout()
    plt.show()

    print("Original Variance :", round(original_var,2))
    print("Mean Fill Variance :", round(mean_var,2))
    print("Median Fill Variance :", round(median_var,2))
    print("Random Fill Variance :", round(random_var,2))

# %%
compare_age_fill_visualization(train_test)
# Out:
# Original Variance : 207.75
# Mean Fill Variance : 165.98
# Median Fill Variance : 166.55
# Random Fill Variance : 204.88

# %%
#Conclusion:

#Mean and median imputation reduce variance and may distort the original distribution.
#Random imputation preserves the distribution more effectively.
#Random filling is often preferred when maintaining the dataset's original characteristics is important.

# %%
bins=[0,2,12,19,30,60,100]
labels= ['Infans','Children','Teens','Young Adults','Adults','seniors']
train_test['Age_Group']=pd.cut(train_test['Age'],bins=bins,labels=labels,right=True)
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
new_train_test = train_test.copy()
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test.loc[
    new_train_test['Age'].isnull(),
    'Age'
] = new_train_test['Age'].dropna().sample(
    new_train_test['Age'].isnull().sum(),
    random_state=42
).values

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
Embarked_Mode = new_train_test['Embarked'].mode()[0]

# %%
Embarked_Mode
# Out:
# 'S'

# %%
new_train_test.loc[
    new_train_test['Embarked'].isnull(),
    'Embarked'
] = new_train_test['Embarked'].dropna().sample(
    new_train_test['Embarked'].isnull().sum(),
    random_state=42
).values

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test['Fare'] = new_train_test['Fare'].fillna(
    new_train_test['Fare'].median()
)

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test['FarePerPerson'] = new_train_test['FarePerPerson'].fillna(
    new_train_test['FarePerPerson'].median()
)

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test['Age'].isnull().sum()
# Out:
# 0

# %%
new_train_test['Survived'].isnull().sum()
# Out:
# 418

# %%
new_train_test['Embarked'].isnull().sum()
# Out:
# 0

# %%
new_train_test['Fare'].isnull().sum()
# Out:
# 0

# %%
new_train_test['FarePerPerson'].isnull().sum()
# Out:
# 0

# %%
bins=[0,2,12,19,30,60,100]
labels= ['Infans','Children','Teens','Young Adults','Adults','seniors']
new_train_test['Age_Group']=pd.cut(new_train_test['Age'],bins=bins,labels=labels,right=True)
new_train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
new_train_test['Age_Group'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1309 entries, 0 to 1308
# Series name: Age_Group
# Non-Null Count  Dtype
# --------------  -----
# 1309 non-null   category
# dtypes: category(1)
# memory usage: 1.6 KB

# %%
sns.boxplot(x=train_test['Fare'])

plt.title("Fare Outliers")
plt.show()

# %%
def handle_outliers_clip(new_train_test, col):

    nums = new_train_test[col].dropna().tolist()

    if len(nums) < 4:
        print(f"Not enough data points in {col} to calculate quartiles.")
        return new_train_test

    length = len(nums)
    order = sorted(nums)

    # Quartiles Position
    Q1 = (25 * (length + 1)) / 100
    Q2 = (50 * (length + 1)) / 100
    Q3 = (75 * (length + 1)) / 100

    def calculate_quartile(Q):

        if Q != int(Q):
            lower_index = int(Q) - 1
            upper_index = lower_index + 1

            # Safety Check
            if upper_index >= len(order):
                return order[-1]

            fraction = Q - int(Q)

            lower_value = order[lower_index]
            upper_value = order[upper_index]

            return lower_value + (fraction * (upper_value - lower_value))

        else:
            return order[int(Q) - 1]

    # Calculate Quartiles
    q1 = calculate_quartile(Q1)
    q2 = calculate_quartile(Q2)
    q3 = calculate_quartile(Q3)

    # IQR
    iqr = q3 - q1

    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)

    # Outliers Before Clipping
    outliers_before = new_train_test[
        (new_train_test[col] < lower_bound) |
        (new_train_test[col] > upper_bound)
    ][col]

    print("=" * 50)
    print(f"Column : {col}")
    print(f"Q1           : {q1:.2f}")
    print(f"Median (Q2)  : {q2:.2f}")
    print(f"Q3           : {q3:.2f}")
    print(f"IQR          : {iqr:.2f}")
    print(f"Lower Bound  : {lower_bound:.2f}")
    print(f"Upper Bound  : {upper_bound:.2f}")
    print(f"Outliers Before : {len(outliers_before)}")

    # Clip Outliers
    new_train_test[col] = new_train_test[col].clip(
        lower=lower_bound,
        upper=upper_bound
    )

    # Outliers After Clipping
    outliers_after = new_train_test[
        (new_train_test[col] < lower_bound) |
        (new_train_test[col] > upper_bound)
    ][col]

    print(f"Outliers After  : {len(outliers_after)}")
    print("=" * 50)

    return new_train_test

# %%
handle_outliers_clip(new_train_test, 'Fare').head()
# Out:
# ...
# Column : Fare
# Q1           : 7.90
# Median (Q2)  : 14.45
# Q3           : 31.27
# IQR          : 23.38
# Lower Bound  : -27.17
# Upper Bound  : 66.34
# Outliers Before : 171
# Outliers After  : 0
# ...
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# ...

# %%
sns.boxplot(x=new_train_test['Fare'])

plt.title("Fare Outliers")
plt.show()

# %%
#Conclusion:

#Outlier treatment successfully reduced extreme Fare values.
#The distribution became more balanced.
#The feature is now more suitable for machine learning models.

# %%
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      1309 non-null   int64
#  1   Survived         891 non-null    float64
#  2   Pclass           1309 non-null   int64
#  3   Name             1309 non-null   object
#  4   Sex              1309 non-null   object
#  5   Age              1046 non-null   float64
#  6   SibSp            1309 non-null   int64
#  7   Parch            1309 non-null   int64
#  8   Ticket           1309 non-null   object
#  9   Fare             1308 non-null   float64
#  10  Cabin            295 non-null    object
#  11  Embarked         1307 non-null   object
#  12  FamilySize       1309 non-null   int64
#  13  FamilyType       1309 non-null   object
#  14  FarePerPerson    1308 non-null   float64
#  15  NameTitle        1309 non-null   object
# ...

# %% [markdown]
# # Overall Conclusion

# %%
#Dataset Insights
#Gender is one of the strongest factors affecting survival; females survived at much higher rates than males.
#Passenger class significantly influenced survival, with First Class passengers having the highest survival probability.
#Higher ticket fares are associated with better survival chances.
#Small family groups generally had better survival outcomes than passengers traveling alone or in very large families.
#Children tended to have higher survival rates compared to many adult groups.
#Embarkation port also shows some relationship with survival, likely due to its connection with passenger class and fare.
#Fare contains substantial outliers that required treatment.
#Missing values, especially in Age, were handled carefully through imputation techniques.
#Engineered features such as FamilySize, FamilyType, Age_Group, and TicketGroupSize provided additional insights and improved predictive potential.
